# %%
__author__ = "Cindy Wang"
__version__ = "Alibaba August 2018"

# %% [markdown]
# # Setup
#
# The following packages are required:
# ```
# numpy==1.14.0
# scipy==1.0.0
# scikit-learn >= 0.19.1
# jupyter==1.0.0
# ```
#
# You can paste these into a `requirements.txt` file and run
# `pip install -r requirements.txt`. You will also need to install Tensorflow by following the instructions on the [website](https://www.tensorflow.org/install/).
#
# ## Running the notebook
# Navigate to your notebooks directory (wherever this file is located) and run `jupyter notebook --port 5656` to start the notebook server.

# %% [markdown]
# # RNNs
#
# Recall the most basic artifical neural network, an MLP (multi-layer perceptron, or feed-forward neural network). Each layer of this network has its own weights $W$, biases $b$, and activation function $f$. These are applied, then the activations are sent to the next layer. The following set of equations describes an $l$-layer MLP:
#
# $$\begin{align}
# z^{(2)} &= W^{(1)} x + b^{(1)} \\
# h^{(2)} &= f(z^{(2)}) \\
# z^{(3)} &= W^{(2)} h^{(2)} + b^{(2)} \\
# h^{(3)} &= f(z^{(3)}) \\
# &\dots \\
# z^{(l+1)} &= W^{(l)} h^{(l)} + b^{(l)}   \\
# h^{(l+1)} &= f(z^{(l+1)}) \\
# y &= softmax(h^{(l+1)})
# \end{align}$$
#
# Now imagine that our inputs are sequential. Our objective is now to capture relationships between successive inputs. We can achieve this by feeding **successive inputs** to **successive hidden layers**. In the diagram below, inputs are passed through identical copies of the neural network layer $A$.
# ![rnn1](img/rnn1.png)
#
# This is essentially what an RNN is.
# ![rnn2](img/rnn2.png)

# %% [markdown]
# ## The problem with RNNs

# %% [markdown]
# $$\textbf{h}_t = \sigma (\textbf{Ux}_t + \textbf{Vh}_{t-1})$$
#
# $$\textbf{h}_t = \sigma (\textbf{Ux}_t + \textbf{V}(\sigma(\textbf{Ux}_{t-1} + \textbf{V}(\sigma(\textbf{Ux}_{t-2})))$$
#
# $$\frac{\partial E_3}{\partial U} = \frac{\partial E_3}{\partial out_3}\frac{\partial out_3}{\partial h_3}\frac{\partial h_3}{\partial h_2}\frac{\partial h_2}{\partial h_1}\frac{\partial h_1}{\partial U}$$

# %% [markdown]
# ![sigmoid gradient](img/Sigmoid-gradient.png)

# %% [markdown]
# # LSTMs

# %% [markdown]
# $$\text{loss} = -\frac{1}{N}\sum_{i=1}^{N} \ln p_{\text{target}_i}$$

# %% [markdown]
# ## The Echo LSTM: A simple working example
# We will go through a basic example that involves feeding a sequence of IDs (numbers) into an LSTM one at a time. (For NLP, these IDs would be the IDs of words in the vocabulary.) Our goal is for the network to echo back a partial or full list of contiguous observations observed.
#
# While this seems overly simplistic, we can think of it as machine translation from L1 to L2, where L1=L2. This requires the network to remember blocks of contiguous observations and demonstrates the LSTM's ability to encode temporal information in low dimensions.

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import random
import sys

# %% [markdown]
# ## Generate sequence
# Normally we would convert sequences of words into a sequences of IDs, but since we are only interested in echoing the sequence, we will just generate it randomly.

# %%
def generate_sequence(num_seq, length):
    return np.random.randint(100, size=(num_seq, length))

# %% [markdown]
# ## Encode sequence
# In the previous lesson, we learned about word embeddings. Here we initialize them randomly, but these can be initialized with pretrained word2vec or GloVe as well.
#
# Since our vocabulary is small, another option is to use one-hot encoding.
# ```
# [0,1,2] -> [[1., 0., 0.],
#             [0., 1., 0.],
#             [0., 0., 1.]]
# ```

# %%
def embedding_encode(ids, vocab_size=100, embedding_size=100):
    with tf.variable_scope('word_embedding'):
        # Embedding matrix
        C = tf.get_variable('C', [vocab_size, embedding_size], initializer=tf.random_normal_initializer())
        return tf.nn.embedding_lookup(C, ids)
                        
def one_hot_encode(ids, vocab_size=100):
    return tf.one_hot(ids, vocab_size)

# %% [markdown]
# ## Create training set
#
# blah

# %%
from sklearn.model_selection import train_test_split

def get_data(n_in, n_out, size=10000):
    X = generate_sequence(size, n_in)
    y = X[:,:n_out]
    return X, y

n_in = 5
n_out = 2
X, y = get_data(n_in, n_out)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
class BasicEncoderDecoder(object):
    """
    Adapted from Chris Potts's CS224U model classes (https://github.com/cgpotts/cs224u)
    
    Parameters
    ----------
    embed_dim : int
        Dimensionality of embeddings (if one-hot, size of vocab).
    cell_class : tf.nn.rnn_cell class
       The default is `tf.nn.rnn_cell.LSTMCell`. Other prominent options:
       `tf.nn.rnn_cell.BasicRNNCell`, and `tf.nn.rnn_cell.GRUCell`.
    hidden_dim : int
        Dimensionality of hidden layers.
    hidden_activation : tf.nn activation
       E.g., tf.nn.relu, tf.nn.relu, tf.nn.selu.
    max_iter : int
    eta : float
        Learning rate
    tol : float
        Stopping criterion for the loss.
    display_progress : int
        For value i, progress is printed every ith iteration.
    Attributes
    ----------
    errors : list
        Tracks loss from each iteration during training.
    """
    def __init__(self, 
                 embed_dim=100,
                 cell_class=tf.nn.rnn_cell.LSTMCell,
                 hidden_dim=150, 
                 hidden_activation=tf.nn.tanh,
                 batch_size=200, 
                 eta=0.01, 
                 tol=1e-4, 
                 display_progress=1):
        self.embed_dim = embed_dim
        self.cell_class = cell_class
        self.hidden_dim = hidden_dim
        self.hidden_activation = hidden_activation
        self.batch_size = batch_size
        self.eta = eta
        self.tol = tol
        self.display_progress = display_progress
    
    def encoder(self, encoder_inputs):
        with tf.variable_scope("encoder"):
            # Declaring LSTM cell
            encoder_cell = self.cell_class(
                self.hidden_dim, activation=self.hidden_activation)
            # Declaring RNN with above cell
            return tf.nn.dynamic_rnn(
                encoder_cell,
                encoder_inputs,
                dtype=tf.float32)
            
    def decoder(self, encoder_state, decoder_inputs):
        with tf.variable_scope("decoder"):
            # Need to declare again
            decoder_cell = self.cell_class(
                self.hidden_dim, activation=self.hidden_activation)
            decoder_outputs, _ = tf.nn.dynamic_rnn(
                decoder_cell, 
                decoder_inputs, 
                initial_state=encoder_state)
            return tf.layers.dense(decoder_outputs, self.embed_dim)
        
    def enc_dec_body(self, inputs):
        _, encoder_state = self.encoder(inputs)
        decoder_inputs = tf.tile(tf.expand_dims(encoder_state.h, 1), (1, self.trg_len, 1))
        return self.decoder(encoder_state, decoder_inputs)
            
    def to_embedding(self, ids):
        # Can alternatively use random, word2vec, or GloVe embeddings
        return tf.one_hot(ids, self.embed_dim)
    
    def shift_left_3d(self, x):
        """Shift the second dimension of x right by one."""
        return tf.pad(x, [[0, 0], [1, 0], [0, 0]])[:, :-1, :]
        
    def fit(self, X, y, max_iter=100, log_msg="", **kwargs):
        """Standard `fit` method.
        Parameters
        ----------
        X : [n x src_len] int
        y : [n x trg_len] int

        Returns
        -------
        self
        """
        if isinstance(X, pd.DataFrame):
            X = X.values

        self.src_len = len(X[0])
        self.trg_len = len(y[0]) 

        # Start the session:
        tf.reset_default_graph()
        self.sess = tf.InteractiveSession()

        # Declare the inputs and outputs
        self.src = tf.placeholder(
            tf.int32, [None, self.src_len])
        self.trg = tf.placeholder(
            tf.int32, shape=[None, None])
        inputs = self.to_embedding(self.src)
        outputs = self.to_embedding(self.trg)
        
        # Build the encoder-decoder body.
        self.model = self.enc_dec_body(inputs)

        # Optimizer set-up:
        self.cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(
                logits=self.model, labels=outputs))
        self.optimizer = tf.train.AdamOptimizer(self.eta).minimize(self.cost)
        self.pred = tf.argmax(tf.nn.softmax(self.model), axis=2)
        self.accuracy = tf.metrics.accuracy(self.trg, self.pred)

        # Initialize the session variables:
        self.sess.run(tf.global_variables_initializer())
        self.sess.run(tf.local_variables_initializer())

        # Training, full dataset for each iteration:
        for i in range(1, max_iter+1):
            loss = 0
            acc = []
            for X_batch, y_batch in self.batch_iterator(X, y):
                _, batch_loss, batch_acc = self.sess.run(
                    [self.optimizer, self.cost, self.accuracy],
                    feed_dict={
                        self.src: X,
                        self.trg: y
                    })
                loss += batch_loss
                acc.append(batch_acc[1])
            acc = sum(acc)/len(acc)
            if loss < self.tol:
                self._progressbar("stopping with loss < self.tol", i)
                break
            else:
                self._progressbar("loss: {}, accuracy: {}".format(loss, acc), i)
        return self
    
    def batch_iterator(self, X, y):
        dataset = list(zip(X, y))
        random.shuffle(dataset)
        for i in range(0, len(dataset), self.batch_size):
            batch = dataset[i: i+self.batch_size]
            X_batch, y_batch = zip(*batch)
            yield X_batch, y_batch

    def predict(self, X, y=None, report_acc=False):
        """Return target sequence
        Parameters
        ----------
        X : np.array
        Returns
        -------
        list
        """
        if report_acc:
            if y is None:
                raise ValueError
            return self.sess.run(
                [self.pred, self.accuracy], feed_dict={self.src: X, self.trg: y})
        return self.sess.run([self.pred], feed_dict={self.src: X})[0]
    
    def _progressbar(self, msg, index):
        if self.display_progress and index % self.display_progress == 0:
            sys.stderr.write('\r')
            sys.stderr.write('Iter {}: {}'.format(index, msg))
            sys.stderr.flush()

# %%
bed = BasicEncoderDecoder()
bed.fit(X_train, y_train, max_iter=25)
# Out:
# Iter 25: loss: 0.0139156941732, accuracy: 0.972046352923

# %%
preds, acc = bed.predict(X_test, y_test, report_acc=True)
print "Accuracy: ", acc[1]
for y, yp in zip(y_test, preds):
    print y, yp, y==yp
# Out:
# Accuracy:  0.97259635
# [19 13] [19 13] [ True  True]
# [88 23] [88 23] [ True  True]
# [ 4 24] [ 4 24] [ True  True]
# [22 60] [22 60] [ True  True]
# [17 62] [17 62] [ True  True]
# [92 36] [92 36] [ True  True]
# [22 68] [22 68] [ True  True]
# [51 59] [51 59] [ True  True]
# [67 93] [67 93] [ True  True]
# [70 49] [70 49] [ True  True]
# [65 86] [65 86] [ True  True]
# [65 66] [65 66] [ True  True]
# [22 47] [22 47] [ True  True]
# [44 62] [44 62] [ True  True]
# [43 75] [43 75] [ True  True]
# [18 25] [18 25] [ True  True]
# [65  5] [65  5] [ True  True]
# [62 82] [62 82] [ True  True]
# [83 96] [83 96] [ True  True]
# [39 19] [39 19] [ True  True]
# [75 36] [75 36] [ True  True]
# [36 24] [36 24] [ True  True]
# [26 22] [26 22] [ True  True]
# [93  7] [93  7] [ True  True]
# [71  5] [71  5] [ True  True]
# [19 48] [19 48] [ True  True]
# [48 34] [48 34] [ True  True]
# [81 92] [81 81] [ True False]
# [71 34] [71 34] [ True  True]
# [74 24] [74 24] [ True  True]
# [79 12] [79 12] [ True  True]
# [96 87] [96 87] [ True  True]
# [62 77] [62 77] [ True  True]
# [12 65] [12 65] [ True  True]
# [39 24] [39 24] [ True  True]
# [73 82] [73 82] [ True  True]
# [89 30] [89 30] [ True  True]
# [26 22] [26 22] [ True  True]
# [84 22] [84 22] [ True  True]
# [27 47] [27 47] [ True  True]
# [64 79] [64 79] [ True  True]
# [71 35] [71 35] [ True  True]
# [97 14] [97 14] [ True  True]
# [55 44] [55 44] [ True  True]
# [ 5 71] [ 5 71] [ True  True]
# [84 85] [84 85] [ True  True]
# [74  3] [74  3] [ True  True]
# [54  9] [54  9] [ True  True]
# [24 83] [24 83] [ True  True]
# [52 96] [52 96] [ True  True]
# [85 34] [85 34] [ True  True]
# [34 19] [34 19] [ True  True]
# [ 0 85] [ 0 85] [ True  True]
# [25 50] [25 50] [ True  True]
# [71 35] [71 35] [ True  True]
# [78  9] [78  9] [ True  True]
# [47 96] [96 96] [False  True]
# [82 59] [82 59] [ True  True]
# [92 65] [92 65] [ True  True]
# [48 80] [48 80] [ True  True]
# [95 17] [95 17] [ True  True]
# [ 8 10] [ 8 10] [ True  True]
# [77 64] [77 64] [ True  True]
# [54 33] [54 33] [ True  True]
# [90 61] [90 61] [ True  True]
# [61 84] [61 84] [ True  True]
# [99  6] [99  6] [ True  True]
# [ 6 31] [ 6 31] [ True  True]
# [12 28] [12 28] [ True  True]
# [46 35] [46 35] [ True  True]
# [65 51] [65 51] [ True  True]
# [97 84] [97 84] [ True  True]
# [85 14] [85 14] [ True  True]
# [99  9] [99  9] [ True  True]
# [12 45] [12 45] [ True  True]
# [20 53] [20 53] [ True  True]
# [50 80] [50 80] [ True  True]
# [28 72] [28 72] [ True  True]
# [60 98] [60 98] [ True  True]
# [29 14] [29 14] [ True  True]
# [72 16] [72 16] [ True  True]
# [22 51] [22 51] [ True  True]
# [ 8 75] [ 8 75] [ True  True]
# [38 20] [38 20] [ True  True]
# [76 41] [76 41] [ True  True]
# [98 22] [98 22] [ True  True]
# [38 31] [38 31] [ True  True]
# [76 55] [76 55] [ True  True]
# [66 53] [66 53] [ True  True]
# [56 25] [56 25] [ True  True]
# [99 52] [99 52] [ True  True]
# [54 58] [54 58] [ True  True]
# [ 8 45] [ 8 45] [ True  True]
# [98 54] [98 54] [ True  True]
# [75 88] [75 88] [ True  True]
# [16 59] [16 59] [ True  True]
# [61 53] [61 53] [ True  True]
# [67 90] [67 90] [ True  True]
# [97 87] [97 87] [ True  True]
# [12 27] [12 27] [ True  True]
# [74 84] [74 84] [ True  True]
# [88 93] [88 93] [ True  True]
# [65 60] [65 60] [ True  True]
# [13  5] [13 13] [ True False]
# [55 77] [55 77] [ True  True]
# [45 11] [45 11] [ True  True]
# [13 38] [13 38] [ True  True]
# [ 6 56] [ 6 56] [ True  True]
# [96 28] [96 28] [ True  True]
# [26 41] [26 41] [ True  True]
# [22 50] [22 50] [ True  True]
# [ 5 98] [ 5 98] [ True  True]
# [64 45] [64 45] [ True  True]
# [56 39] [56 39] [ True  True]
# [53 82] [53 82] [ True  True]
# [97 77] [97 77] [ True  True]
# [30 42] [30 42] [ True  True]
# [23 94] [23 94] [ True  True]
# [14 82] [14 82] [ True  True]
# [ 7 61] [ 7 61] [ True  True]
# [58 89] [58 89] [ True  True]
# [ 5 56] [ 5 56] [ True  True]
# [37  7] [37  7] [ True  True]
# [ 1 82] [ 1 82] [ True  True]
# [14 41] [14 41] [ True  True]
# [19 78] [19 78] [ True  True]
# [48 90] [48 90] [ True  True]
# [94 34] [94 34] [ True  True]
# [42 81] [42 81] [ True  True]
# [91 27] [91 27] [ True  True]
# [58 13] [58 13] [ True  True]
# [24 67] [24 67] [ True  True]
# [28 86] [28 86] [ True  True]
# [52 11] [52 11] [ True  True]
# [30 75] [30 75] [ True  True]
# [73 62] [73 62] [ True  True]
# [14 40] [14 40] [ True  True]
# [92 32] [92 32] [ True  True]
# [70 66] [70 66] [ True  True]
# [81 48] [81 48] [ True  True]
# [58 63] [58 63] [ True  True]
# [38  4] [38  4] [ True  True]
# [23 68] [23 68] [ True  True]
# [71 96] [71 96] [ True  True]
# [90 76] [90 76] [ True  True]
# [20 57] [20 57] [ True  True]
# [36 18] [36 18] [ True  True]
# [48 76] [48 46] [ True False]
# [62 97] [62 11] [ True False]
# [34 48] [34 48] [ True  True]
# [92 79] [92 79] [ True  True]
# [ 6 27] [ 6 27] [ True  True]
# [29 74] [29 74] [ True  True]
# [31 99] [31 99] [ True  True]
# [5 2] [5 2] [ True  True]
# [65 54] [65 54] [ True  True]
# [34 28] [34 28] [ True  True]
# [96 12] [96 12] [ True  True]
# [33 74] [33 74] [ True  True]
# [28 40] [28 40] [ True  True]
# [41 67] [41 67] [ True  True]
# [51  6] [51  6] [ True  True]
# [69 20] [69 20] [ True  True]
# [86 44] [86 44] [ True  True]
# [ 4 64] [ 4 64] [ True  True]
# [90 15] [90 15] [ True  True]
# [49 67] [49 67] [ True  True]
# [18  2] [18  2] [ True  True]
# [ 1 36] [ 1 36] [ True  True]
# [71 72] [71 72] [ True  True]
# [59 83] [59 83] [ True  True]
# [64 54] [64 54] [ True  True]
# [28 96] [28 96] [ True  True]
# [49  0] [49  0] [ True  True]
# [91 59] [91 59] [ True  True]
# [11 17] [11 17] [ True  True]
# [36  9] [36  9] [ True  True]
# [62 38] [62 38] [ True  True]
# [11 80] [11 80] [ True  True]
# [ 1 19] [ 1 19] [ True  True]
# [31 43] [31 43] [ True  True]
# [67 72] [67 72] [ True  True]
# [41 15] [41 15] [ True  True]
# [ 8 48] [ 8 48] [ True  True]
# [ 4 31] [ 4 31] [ True  True]
# [60 18] [60 18] [ True  True]
# [19 56] [19 56] [ True  True]
# [70 83] [70 83] [ True  True]
# [16 88] [16 88] [ True  True]
# [35 13] [35 13] [ True  True]
# [89 17] [89 17] [ True  True]
# [92 54] [92 54] [ True  True]
# [26 72] [26 72] [ True  True]
# [94 69] [94 69] [ True  True]
# [19 15] [19 15] [ True  True]
# [75 69] [75 69] [ True  True]
# [62 32] [62 32] [ True  True]
# [73  0] [73  0] [ True  True]
# [11 24] [11 24] [ True  True]
# [92 23] [92 23] [ True  True]
# [1 6] [1 6] [ True  True]
# [93 84] [93 84] [ True  True]
# [12 24] [12 24] [ True  True]
# [14 23] [14 23] [ True  True]
# [58 42] [58 42] [ True  True]
# [30 26] [30 26] [ True  True]
# [ 4 66] [ 4 66] [ True  True]
# [32 11] [32 11] [ True  True]
# [49 47] [49 47] [ True  True]
# [75  3] [75  3] [ True  True]
# [73 17] [73 17] [ True  True]
# [29 67] [29 67] [ True  True]
# [79 18] [79 18] [ True  True]
# [84 35] [84 35] [ True  True]
# [41 37] [41 37] [ True  True]
# [63 36] [63 36] [ True  True]
# [91 76] [91 76] [ True  True]
# [32 88] [32 88] [ True  True]
# [44 93] [44 93] [ True  True]
# [94 75] [94 75] [ True  True]
# [92 54] [92 54] [ True  True]
# [95 84] [95 84] [ True  True]
# [21 69] [21 69] [ True  True]
# [20 96] [20 96] [ True  True]
# [57 31] [57 31] [ True  True]
# [94 44] [94 44] [ True  True]
# [ 1 46] [ 1 46] [ True  True]
# [86 89] [86 89] [ True  True]
# [99 79] [99 79] [ True  True]
# [96 73] [96 73] [ True  True]
# [62 36] [62 36] [ True  True]
# [21 56] [21 56] [ True  True]
# [33 71] [33 71] [ True  True]
# [38 59] [38 59] [ True  True]
# [28 55] [28 55] [ True  True]
# [54 53] [54 53] [ True  True]
# [98 43] [98 43] [ True  True]
# [62 44] [62 44] [ True  True]
# [46 53] [46 53] [ True  True]
# [28 29] [28 29] [ True  True]
# [66  4] [66  4] [ True  True]
# [56 16] [56 16] [ True  True]
# [22 65] [22 65] [ True  True]
# [22 77] [22 77] [ True  True]
# [ 5 49] [ 5 49] [ True  True]
# [64 88] [64 88] [ True  True]
# [28 21] [28 21] [ True  True]
# [97 20] [97 20] [ True  True]
# [60 80] [60 80] [ True  True]
# [48 41] [48 41] [ True  True]
# [58 37] [58 37] [ True  True]
# [58 91] [58 91] [ True  True]
# [80 25] [80 25] [ True  True]
# [12  2] [12  2] [ True  True]
# [40 47] [40 47] [ True  True]
# [37 54] [37 54] [ True  True]
# [18 80] [18 80] [ True  True]
# [ 8 44] [ 8 44] [ True  True]
# [65 88] [65 88] [ True  True]
# [ 6 23] [ 6 23] [ True  True]
# [95 68] [95 68] [ True  True]
# [34 48] [34 48] [ True  True]
# [33 92] [33 92] [ True  True]
# [ 0 36] [ 0 36] [ True  True]
# [18 24] [18 24] [ True  True]
# [48 48] [48 48] [ True  True]
# [67 10] [67 10] [ True  True]
# [80 36] [80 36] [ True  True]
# [98 78] [98 78] [ True  True]
# [47 55] [47 55] [ True  True]
# [46 35] [46 46] [ True False]
# [97 54] [97 54] [ True  True]
# [87 57] [87 57] [ True  True]
# [43 49] [43 49] [ True  True]
# [63 15] [63 15] [ True  True]
# [65 37] [65 37] [ True  True]
# [13 24] [13 13] [ True False]
# [97 81] [97 81] [ True  True]
# [16 13] [16 13] [ True  True]
# [33 69] [33 69] [ True  True]
# [90 28] [90 28] [ True  True]
# [56 49] [56 49] [ True  True]
# [38 81] [38 81] [ True  True]
# [61 55] [61 55] [ True  True]
# [69  5] [69  5] [ True  True]
# [69 12] [69 12] [ True  True]
# [62 92] [62 92] [ True  True]
# [16 12] [16 12] [ True  True]
# [82 55] [82 55] [ True  True]
# [80  4] [80  4] [ True  True]
# [50 95] [50 95] [ True  True]
# [72 58] [72 58] [ True  True]
# [69 10] [69 10] [ True  True]
# [34 37] [34 37] [ True  True]
# [27 89] [27 89] [ True  True]
# [76  0] [76  0] [ True  True]
# [46  8] [46 41] [ True False]
# [34 53] [34 53] [ True  True]
# [42 15] [42 15] [ True  True]
# [11 42] [11 42] [ True  True]
# [69 87] [69 87] [ True  True]
# [75 88] [75 88] [ True  True]
# [30 29] [30 29] [ True  True]
# [44 53] [44 53] [ True  True]
# [ 1 36] [ 1 36] [ True  True]
# [56 35] [56 35] [ True  True]
# [51 88] [51 88] [ True  True]
# [76 36] [76 36] [ True  True]
# [85 46] [85 46] [ True  True]
# [72 75] [72 75] [ True  True]
# [27 79] [27 79] [ True  True]
# [54 45] [54 45] [ True  True]
# [17 46] [17 46] [ True  True]
# [97 60] [97 60] [ True  True]
# [11 32] [11 32] [ True  True]
# [75 34] [75 34] [ True  True]
# [19  0] [19  0] [ True  True]
# [43 52] [43 52] [ True  True]
# [ 0 32] [ 0 32] [ True  True]
# [7 6] [7 6] [ True  True]
# [98 93] [98 93] [ True  True]
# [95 27] [95 27] [ True  True]
# [25 95] [25 95] [ True  True]
# [97 34] [97  9] [ True False]
# [53 29] [53 29] [ True  True]
# [60 84] [60 84] [ True  True]
# [16 35] [16 35] [ True  True]
# [84 14] [84 14] [ True  True]
# [90 89] [90 89] [ True  True]
# [84 59] [84 59] [ True  True]
# [ 2 37] [ 2 37] [ True  True]
# [19 45] [19 45] [ True  True]
# [ 6 64] [ 6 64] [ True  True]
# [21 77] [21 77] [ True  True]
# [72 71] [72 71] [ True  True]
# [24 77] [24 77] [ True  True]
# [72 81] [72 81] [ True  True]
# [60 87] [60 87] [ True  True]
# [31 60] [31 60] [ True  True]
# [44 44] [44 44] [ True  True]
# [ 2 52] [ 2 52] [ True  True]
# [68 32] [68 32] [ True  True]
# [19 86] [19 86] [ True  True]
# [28 68] [28 68] [ True  True]
# [5 3] [5 3] [ True  True]
# [1 0] [1 0] [ True  True]
# [13 54] [13 54] [ True  True]
# [22 36] [22 36] [ True  True]
# [11 13] [11 13] [ True  True]
# [65 77] [65 77] [ True  True]
# [64 75] [64 75] [ True  True]
# [16 39] [16 39] [ True  True]
# [86 41] [86 41] [ True  True]
# [65  2] [65  2] [ True  True]
# [93 37] [93 37] [ True  True]
# [14 55] [14 55] [ True  True]
# [78 16] [78 16] [ True  True]
# [48 97] [48 97] [ True  True]
# [43 80] [43 80] [ True  True]
# [13 99] [13 99] [ True  True]
# [20  2] [20  2] [ True  True]
# [93 13] [93 13] [ True  True]
# [31 82] [31 82] [ True  True]
# [75  7] [75  7] [ True  True]
# [99 91] [99 99] [ True False]
# [ 3 56] [ 3 56] [ True  True]
# [91 83] [91 83] [ True  True]
# [78 12] [78 12] [ True  True]
# [23 87] [23 87] [ True  True]
# [43 53] [43 53] [ True  True]
# [31 82] [31 82] [ True  True]
# [72  5] [72  5] [ True  True]
# [14 47] [14 47] [ True  True]
# [80 39] [80 39] [ True  True]
# [12 29] [12 29] [ True  True]
# [53 94] [53 94] [ True  True]
# [56 61] [56 61] [ True  True]
# [22 60] [22 60] [ True  True]
# [47 90] [47 47] [ True False]
# [86 80] [86 80] [ True  True]
# [66 12] [66 12] [ True  True]
# [70 31] [70 31] [ True  True]
# [89 91] [89 91] [ True  True]
# [59 89] [59 89] [ True  True]
# [12 45] [12 45] [ True  True]
# [26 29] [26 29] [ True  True]
# [98 70] [98 70] [ True  True]
# [93 60] [93 60] [ True  True]
# [52 73] [52 73] [ True  True]
# [69 33] [69 33] [ True  True]
# [70  1] [70  1] [ True  True]
# [70 68] [70 68] [ True  True]
# [31 77] [31 77] [ True  True]
# [42  7] [42  7] [ True  True]
# [97  8] [97  8] [ True  True]
# [85 61] [85 85] [ True False]
# [3 4] [3 4] [ True  True]
# [47 98] [47 98] [ True  True]
# [41 79] [41 79] [ True  True]
# [61 29] [61 29] [ True  True]
# [13 64] [13 64] [ True  True]
# [55  2] [55  2] [ True  True]
# [14 95] [14 95] [ True  True]
# [ 1 76] [ 1 76] [ True  True]
# [59 58] [59 58] [ True  True]
# [17 29] [17 29] [ True  True]
# [11 71] [11 11] [ True False]
# [69 90] [69 90] [ True  True]
# [48 52] [48 52] [ True  True]
# [22 91] [22 91] [ True  True]
# [61 11] [61 11] [ True  True]
# [14 76] [14 76] [ True  True]
# [62 21] [62 21] [ True  True]
# [14 82] [14 82] [ True  True]
# [74 48] [74 48] [ True  True]
# [81 89] [81 89] [ True  True]
# [84 23] [84 23] [ True  True]
# [43 22] [43 22] [ True  True]
# [75 46] [75 46] [ True  True]
# [82  8] [82  8] [ True  True]
# [55 17] [55 17] [ True  True]
# [46 67] [46 46] [ True False]
# [69 64] [69 64] [ True  True]
# [98 22] [98 22] [ True  True]
# [17 83] [17 83] [ True  True]
# [34 89] [34 89] [ True  True]
# [19 93] [19 93] [ True  True]
# [19  7] [19  7] [ True  True]
# [86 46] [86 46] [ True  True]
# [34 84] [34 84] [ True  True]
# [11 43] [11 43] [ True  True]
# [ 7 70] [ 7 70] [ True  True]
# [50  0] [50  0] [ True  True]
# [19 79] [19 19] [ True False]
# [ 1 87] [ 1 87] [ True  True]
# [3 0] [3 0] [ True  True]
# [54 96] [54 96] [ True  True]
# [51 65] [51 65] [ True  True]
# [96 25] [96 25] [ True  True]
# [ 4 31] [ 4 31] [ True  True]
# [19 33] [19 19] [ True False]
# [19 30] [19 30] [ True  True]
# [72 26] [72 26] [ True  True]
# [23 19] [23 19] [ True  True]
# [73 54] [73 54] [ True  True]
# [ 9 28] [ 9 28] [ True  True]
# [15 81] [15 95] [ True False]
# [ 0 74] [ 0 74] [ True  True]
# [59 29] [59 19] [ True False]
# [54 20] [54 20] [ True  True]
# [70 64] [70 64] [ True  True]
# [ 7 58] [ 7 58] [ True  True]
# [24 52] [24 52] [ True  True]
# [97 87] [97 87] [ True  True]
# [ 8 58] [ 8 58] [ True  True]
# [67 39] [67 39] [ True  True]
# [26 92] [26 92] [ True  True]
# [54 46] [54 46] [ True  True]
# [10 78] [10 78] [ True  True]
# [19 24] [19 24] [ True  True]
# [24 52] [24 52] [ True  True]
# [ 0 52] [ 0 52] [ True  True]
# [25 31] [25 31] [ True  True]
# [39 87] [39 87] [ True  True]
# [61 78] [61 78] [ True  True]
# [ 6 26] [ 6 26] [ True  True]
# [90 51] [90 51] [ True  True]
# [86 48] [86 48] [ True  True]
# [ 5 15] [ 5 15] [ True  True]
# [69 99] [69 99] [ True  True]
# [72 39] [72 39] [ True  True]
# [24 16] [24 16] [ True  True]
# [81 34] [81 34] [ True  True]
# [ 0 25] [0 0] [ True False]
# [77  3] [77  3] [ True  True]
# [67 48] [67 48] [ True  True]
# [1 8] [1 8] [ True  True]
# [45 40] [45 40] [ True  True]
# [40 84] [40 84] [ True  True]
# [ 8 86] [ 8 86] [ True  True]
# [75 75] [75 75] [ True  True]
# [55 23] [55 23] [ True  True]
# [ 7 90] [ 7 90] [ True  True]
# [80 52] [80 52] [ True  True]
# [ 4 32] [ 4 32] [ True  True]
# [88 41] [88 41] [ True  True]
# [31 69] [31 69] [ True  True]
# [28 22] [28 22] [ True  True]
# [82 72] [82 72] [ True  True]
# [83 47] [83 47] [ True  True]
# [15 53] [15 53] [ True  True]
# [54 12] [54 12] [ True  True]
# [83 19] [83 19] [ True  True]
# [69 34] [69 69] [ True False]
# [20 54] [20 54] [ True  True]
# [39 16] [39 16] [ True  True]
# [99 24] [99 24] [ True  True]
# [98 95] [98 95] [ True  True]
# [40 81] [40 81] [ True  True]
# [81 48] [81 48] [ True  True]
# [44 51] [44 51] [ True  True]
# [ 6 84] [ 6 84] [ True  True]
# [54 22] [54 22] [ True  True]
# [ 2 51] [ 2 51] [ True  True]
# [ 4 28] [ 4 28] [ True  True]
# [39 71] [39 39] [ True False]
# [68 50] [68 50] [ True  True]
# [72  7] [72 85] [ True False]
# [72 39] [72 39] [ True  True]
# [81 39] [81 39] [ True  True]
# [21 37] [21 37] [ True  True]
# [ 2 51] [ 2 51] [ True  True]
# [99 50] [99 50] [ True  True]
# [75 42] [75 42] [ True  True]
# [17 41] [17 41] [ True  True]
# [ 4 37] [ 4 37] [ True  True]
# [96 69] [96 69] [ True  True]
# [80 86] [80 86] [ True  True]
# [53 19] [53 19] [ True  True]
# [60 78] [60 78] [ True  True]
# [70 58] [70 58] [ True  True]
# [82  3] [82  3] [ True  True]
# [20 50] [20 50] [ True  True]
# [85 67] [85 67] [ True  True]
# [ 3 52] [ 3 52] [ True  True]
# [56 62] [56 62] [ True  True]
# [88 85] [88 85] [ True  True]
# [65 94] [65 94] [ True  True]
# [98 24] [98 24] [ True  True]
# [38 11] [38 11] [ True  True]
# [28 16] [28 16] [ True  True]
# [52 92] [52 92] [ True  True]
# [ 9 43] [ 9 43] [ True  True]
# [22 62] [22 62] [ True  True]
# [17 52] [17 52] [ True  True]
# [93 85] [93 93] [ True False]
# [83 56] [83 83] [ True False]
# [61 90] [61 90] [ True  True]
# [65 83] [65 83] [ True  True]
# [17 77] [17 77] [ True  True]
# [98 61] [98 61] [ True  True]
# [50 72] [50 72] [ True  True]
# [ 8 47] [ 8 47] [ True  True]
# [79 10] [79 10] [ True  True]
# [17 62] [17 62] [ True  True]
# [45 99] [45 99] [ True  True]
# [73 71] [73 71] [ True  True]
# [28 29] [28 29] [ True  True]
# [15 14] [15 85] [ True False]
# [96 21] [96 21] [ True  True]
# [79 65] [79 65] [ True  True]
# [30  6] [30  6] [ True  True]
# [ 8 63] [ 8 63] [ True  True]
# [33 56] [33 56] [ True  True]
# [92 76] [92 76] [ True  True]
# [59 11] [59 11] [ True  True]
# [15 15] [15 15] [ True  True]
# [37 15] [37 15] [ True  True]
# [56 76] [56 76] [ True  True]
# [59 52] [59 52] [ True  True]
# [56 43] [56 43] [ True  True]
# [80 71] [80 71] [ True  True]
# [52 65] [52 65] [ True  True]
# [52 54] [52 54] [ True  True]
# [82 92] [82 92] [ True  True]
# [82 79] [82 79] [ True  True]
# [9 0] [9 9] [ True False]
# [77 26] [77 26] [ True  True]
# [36 28] [36 28] [ True  True]
# [88 77] [88 77] [ True  True]
# [46 79] [46 79] [ True  True]
# [62 42] [62 42] [ True  True]
# [73 94] [73 94] [ True  True]
# [85 15] [85 15] [ True  True]
# [98 23] [98 23] [ True  True]
# [75 20] [75 55] [ True False]
# [43 44] [43 44] [ True  True]
# [71 65] [71 65] [ True  True]
# [87 51] [87 51] [ True  True]
# [59 67] [59 67] [ True  True]
# [48 30] [48 30] [ True  True]
# [83 50] [83 50] [ True  True]
# [50 15] [50 15] [ True  True]
# [42 45] [42 45] [ True  True]
# [58 86] [58 86] [ True  True]
# [39 97] [39 97] [ True  True]
# [72 28] [72 28] [ True  True]
# [48  7] [48  7] [ True  True]
# [78 71] [78 71] [ True  True]
# [50 59] [50 59] [ True  True]
# [24 81] [24 81] [ True  True]
# [73 62] [73 62] [ True  True]
# [88  0] [88  0] [ True  True]
# [42 61] [42 61] [ True  True]
# [26 46] [26 46] [ True  True]
# [45  3] [45  3] [ True  True]
# [95 79] [95 79] [ True  True]
# [61 47] [61 47] [ True  True]
# [25 44] [25 44] [ True  True]
# [80 70] [80 70] [ True  True]
# [15 77] [15 77] [ True  True]
# [78 10] [78 78] [ True False]
# [ 9 86] [ 9 86] [ True  True]
# [60 17] [60 17] [ True  True]
# [71 94] [71 94] [ True  True]
# [23 36] [23 36] [ True  True]
# [ 9 66] [9 9] [ True False]
# [ 7 90] [ 7 90] [ True  True]
# [72 17] [72 17] [ True  True]
# [97 68] [97 68] [ True  True]
# [65 42] [65 42] [ True  True]
# [59  1] [59  1] [ True  True]
# [82 81] [82 81] [ True  True]
# [38 15] [38 15] [ True  True]
# [35 73] [35 73] [ True  True]
# [32 22] [32 22] [ True  True]
# [11 76] [11 76] [ True  True]
# [47 75] [47 75] [ True  True]
# [44 46] [44 46] [ True  True]
# [18 41] [18 41] [ True  True]
# [48 21] [48 21] [ True  True]
# [17 36] [17 36] [ True  True]
# [32 79] [32 79] [ True  True]
# [48 85] [48 85] [ True  True]
# [64  6] [64  6] [ True  True]
# [52 63] [52 63] [ True  True]
# [57 42] [57 42] [ True  True]
# [76 86] [76 86] [ True  True]
# [25  1] [25  1] [ True  True]
# [85 93] [85 93] [ True  True]
# [28 92] [28 92] [ True  True]
# [33 24] [33 24] [ True  True]
# [16 50] [16 50] [ True  True]
# [32 63] [32 63] [ True  True]
# [98 11] [98 11] [ True  True]
# [10 96] [10 96] [ True  True]
# [39 99] [39 99] [ True  True]
# [29 93] [29 93] [ True  True]
# [ 3 46] [ 3 46] [ True  True]
# [63 81] [63 81] [ True  True]
# [40 48] [40 48] [ True  True]
# [71 73] [71 73] [ True  True]
# [82 30] [82 30] [ True  True]
# [37 41] [37 41] [ True  True]
# [39 65] [39 65] [ True  True]
# [81 35] [81 35] [ True  True]
# [77 39] [77 77] [ True False]
# [65 28] [65 28] [ True  True]
# [74 35] [74 35] [ True  True]
# [57 47] [57 47] [ True  True]
# [31 13] [31 13] [ True  True]
# [35 50] [35 50] [ True  True]
# [33 36] [33 36] [ True  True]
# [97 93] [97 93] [ True  True]
# [72 59] [72 59] [ True  True]
# [68 22] [68 22] [ True  True]
# [32 90] [32 90] [ True  True]
# [ 1 73] [ 1 73] [ True  True]
# [42 32] [42 32] [ True  True]
# [91 26] [91 26] [ True  True]
# [11 12] [11 12] [ True  True]
# [84 42] [84 42] [ True  True]
# [38 89] [38 89] [ True  True]
# [97 17] [97 17] [ True  True]
# [83 79] [83 79] [ True  True]
# [41 39] [41 39] [ True  True]
# [71 66] [71 66] [ True  True]
# [29 22] [29 22] [ True  True]
# [90 70] [90 70] [ True  True]
# [24 98] [24 98] [ True  True]
# [77 73] [77 73] [ True  True]
# [55 86] [55 86] [ True  True]
# [60 58] [60 58] [ True  True]
# [7 0] [7 0] [ True  True]
# [27 67] [27 67] [ True  True]
# [ 3 11] [ 3 11] [ True  True]
# [12 86] [12 86] [ True  True]
# [15 75] [15 75] [ True  True]
# [59 45] [59 45] [ True  True]
# [78 29] [78 78] [ True False]
# [55 32] [55 32] [ True  True]
# [42 90] [42 90] [ True  True]
# [34 67] [34 67] [ True  True]
# [93  3] [93  3] [ True  True]
# [85 64] [85 64] [ True  True]
# [90 24] [90 24] [ True  True]
# [90 87] [90 87] [ True  True]
# [ 0 48] [ 0 48] [ True  True]
# [93 53] [93 53] [ True  True]
# [70 93] [70 93] [ True  True]
# [47 46] [47 46] [ True  True]
# [39 19] [39 19] [ True  True]
# [4 0] [4 0] [ True  True]
# [ 4 78] [ 4 78] [ True  True]
# [62 27] [62 27] [ True  True]
# [67  3] [67  3] [ True  True]
# [22 74] [22 74] [ True  True]
# [96 42] [96 42] [ True  True]
# [40 55] [40 55] [ True  True]
# [66 72] [66 72] [ True  True]
# [61 78] [61 78] [ True  True]
# [94 18] [94 18] [ True  True]
# [20 76] [20 76] [ True  True]
# [68 95] [68 95] [ True  True]
# [53 70] [53 70] [ True  True]
# [56 16] [56 16] [ True  True]
# [25 32] [25 32] [ True  True]
# [81 90] [81 90] [ True  True]
# [99 60] [99 60] [ True  True]
# [63  9] [63  9] [ True  True]
# [45  4] [45  4] [ True  True]
# [70 81] [70 81] [ True  True]
# [86 16] [86 83] [ True False]
# [92 78] [92 78] [ True  True]
# [ 0 60] [ 0 60] [ True  True]
# [84 40] [84 40] [ True  True]
# [99 45] [99 45] [ True  True]
# [96 78] [96 78] [ True  True]
# [23 77] [23 77] [ True  True]
# [ 2 71] [ 2 71] [ True  True]
# [46 24] [46 24] [ True  True]
# [44 76] [44 76] [ True  True]
# [22 17] [22 17] [ True  True]
# [46  4] [46  4] [ True  True]
# [47 79] [47 79] [ True  True]
# [63 75] [63 75] [ True  True]
# [ 3 75] [ 3 75] [ True  True]
# [38 31] [38 31] [ True  True]
# [15 57] [15 57] [ True  True]
# [ 2 53] [ 2 53] [ True  True]
# [11 36] [11 36] [ True  True]
# [61 64] [61 64] [ True  True]
# [31  8] [31  7] [ True False]
# [48  6] [48  6] [ True  True]
# [78 35] [78 35] [ True  True]
# [75 84] [75 12] [ True False]
# [87 74] [87 74] [ True  True]
# [25 16] [25 16] [ True  True]
# [23 56] [23 56] [ True  True]
# [83 40] [83 40] [ True  True]
# [4 1] [4 1] [ True  True]
# [43 86] [43 86] [ True  True]
# [81 28] [81 28] [ True  True]
# [59 78] [59 78] [ True  True]
# [15  6] [15  6] [ True  True]
# [57 41] [57 41] [ True  True]
# [62 24] [62 24] [ True  True]
# [60  0] [60  0] [ True  True]
# [42 61] [42 61] [ True  True]
# [ 1 25] [ 1 25] [ True  True]
# [46 22] [46 22] [ True  True]
# [61 94] [61 94] [ True  True]
# [43 91] [43 91] [ True  True]
# [69 84] [69 84] [ True  True]
# [40 50] [40 50] [ True  True]
# [32 70] [32 70] [ True  True]
# [65 92] [65 92] [ True  True]
# [53 13] [53 13] [ True  True]
# [66 79] [66 79] [ True  True]
# [45 74] [45 74] [ True  True]
# [34 87] [34 87] [ True  True]
# [66 74] [66 74] [ True  True]
# [72 98] [72 71] [ True False]
# [51 21] [51 21] [ True  True]
# [75 17] [75 17] [ True  True]
# [55 36] [55 36] [ True  True]
# [40 15] [40 15] [ True  True]
# [79 21] [79 21] [ True  True]
# [30 84] [30 84] [ True  True]
# [37 62] [37 62] [ True  True]
# [20 93] [20 93] [ True  True]
# [21 76] [21 76] [ True  True]
# [32  6] [32  6] [ True  True]
# [61 42] [61 42] [ True  True]
# [70 23] [70 23] [ True  True]
# [30 93] [30 93] [ True  True]
# [16 52] [16 52] [ True  True]
# [30 81] [30 81] [ True  True]
# [52 51] [52 51] [ True  True]
# [80 82] [80 82] [ True  True]
# [34 65] [34 65] [ True  True]
# [66 65] [66 65] [ True  True]
# [57 68] [57 68] [ True  True]
# [87 84] [87 84] [ True  True]
# [43 88] [43 88] [ True  True]
# [59 67] [59 59] [ True False]
# [91 93] [91 93] [ True  True]
# [38  8] [38  8] [ True  True]
# [48 61] [48 61] [ True  True]
# [ 5 27] [ 5 27] [ True  True]
# [ 5 58] [ 5 58] [ True  True]
# [26  7] [26  7] [ True  True]
# [ 9 69] [ 9 69] [ True  True]
# [37 66] [37 66] [ True  True]
# [86  2] [86  2] [ True  True]
# [20 77] [20 77] [ True  True]
# [19 23] [19 23] [ True  True]
# [17 80] [17 80] [ True  True]
# [47 51] [47 51] [ True  True]
# [72 57] [72 57] [ True  True]
# [51 45] [51 45] [ True  True]
# [31 20] [31 20] [ True  True]
# [ 3 88] [ 3 88] [ True  True]
# [13  7] [13  7] [ True  True]
# [47 23] [47 23] [ True  True]
# [84 39] [84 39] [ True  True]
# [70 65] [70 65] [ True  True]
# [38 81] [38 81] [ True  True]
# [99 20] [99 20] [ True  True]
# [26 45] [26 45] [ True  True]
# [88 89] [88 89] [ True  True]
# [58 20] [58 58] [ True False]
# [37 39] [37 39] [ True  True]
# [29 51] [29 51] [ True  True]
# [51 72] [51 72] [ True  True]
# [75 44] [75 44] [ True  True]
# [24 82] [24 82] [ True  True]
# [39 11] [39 11] [ True  True]
# [12 71] [12 71] [ True  True]
# [64 56] [64 56] [ True  True]
# [ 5 60] [ 5 60] [ True  True]
# [57 87] [57 87] [ True  True]
# [39 30] [39 30] [ True  True]
# [41 40] [41 40] [ True  True]
# [58 55] [58 55] [ True  True]
# [12 82] [12 82] [ True  True]
# [ 2 96] [ 2 96] [ True  True]
# [54  1] [54  1] [ True  True]
# [43 60] [43 60] [ True  True]
# [ 9 12] [9 9] [ True False]
# [54 40] [54 40] [ True  True]
# [ 9 78] [ 9 78] [ True  True]
# [93  7] [93  7] [ True  True]
# [32  4] [32  4] [ True  True]
# [81 56] [81 56] [ True  True]
# [50 39] [50 39] [ True  True]
# [40 83] [40 83] [ True  True]
# [97 69] [97 69] [ True  True]
# [70 19] [70 19] [ True  True]
# [91 59] [91 59] [ True  True]
# [ 6 71] [ 6 71] [ True  True]
# [28 89] [28 89] [ True  True]
# [62 67] [62 67] [ True  True]
# [22 16] [22 16] [ True  True]
# [31 47] [31 47] [ True  True]
# [81 59] [81 59] [ True  True]
# [39 18] [39 18] [ True  True]
# [77 22] [77 22] [ True  True]
# [78 97] [78 97] [ True  True]
# [66 73] [66 73] [ True  True]
# [74 48] [74 48] [ True  True]
# [93 98] [93 98] [ True  True]
# [77 86] [77 86] [ True  True]
# [20 41] [20 41] [ True  True]
# [55  2] [55  2] [ True  True]
# [45 13] [45 13] [ True  True]
# [77 99] [77 99] [ True  True]
# [99 62] [99 62] [ True  True]
# [11 89] [11 89] [ True  True]
# [86 34] [86 34] [ True  True]
# [61 67] [61 67] [ True  True]
# [69 69] [69 69] [ True  True]
# [26 99] [26 99] [ True  True]
# [70 38] [70 38] [ True  True]
# [67 57] [67 57] [ True  True]
# [95 10] [95 10] [ True  True]
# [80 64] [80 64] [ True  True]
# [5 6] [5 6] [ True  True]
# [19 34] [19 34] [ True  True]
# [85 13] [85 13] [ True  True]
# [72  3] [72  3] [ True  True]
# [71 16] [71 16] [ True  True]
# [84 95] [84 95] [ True  True]
# [67 83] [67 83] [ True  True]
# [78 22] [78 22] [ True  True]
# [68 25] [68 25] [ True  True]
# [99  9] [99  9] [ True  True]
# [39 10] [39 10] [ True  True]
# [24 30] [24 30] [ True  True]
# [92 36] [92 36] [ True  True]
# [89 39] [89 39] [ True  True]
# [95 13] [95 13] [ True  True]
# [86 30] [86 30] [ True  True]
# [49 32] [49 32] [ True  True]
# [11 60] [11 60] [ True  True]
# [19 66] [19 66] [ True  True]
# [47 77] [47 77] [ True  True]
# [31 31] [31 31] [ True  True]
# [54 60] [54 60] [ True  True]
# [73 41] [73 41] [ True  True]
# [41 90] [41 90] [ True  True]
# [38 49] [38 49] [ True  True]
# [44 71] [44 71] [ True  True]
# [27 49] [27 49] [ True  True]
# [58 96] [58 96] [ True  True]
# [72 21] [72 21] [ True  True]
# [91 45] [91 45] [ True  True]
# [49 66] [49 66] [ True  True]
# [74 38] [74 38] [ True  True]
# [95 14] [95 14] [ True  True]
# [11  0] [11  0] [ True  True]
# [76  7] [76  7] [ True  True]
# [44 64] [44 64] [ True  True]
# [73 97] [73 97] [ True  True]
# [75  2] [75  2] [ True  True]
# [42 29] [42 29] [ True  True]
# [85 82] [85 82] [ True  True]
# [57 51] [57 51] [ True  True]
# [21 88] [21 88] [ True  True]
# [29 11] [29 11] [ True  True]
# [90 42] [90 42] [ True  True]
# [80 58] [80 58] [ True  True]
# [54 53] [54 53] [ True  True]
# [25 36] [25 36] [ True  True]
# [ 1 92] [ 1 92] [ True  True]
# [92 86] [92 86] [ True  True]
# [76 84] [76 84] [ True  True]
# [27 45] [27 45] [ True  True]
# [45 36] [45 36] [ True  True]
# [70  5] [70  5] [ True  True]
# [90 25] [90 25] [ True  True]
# [10 39] [10 39] [ True  True]
# [90 24] [90 24] [ True  True]
# [ 8 93] [ 8 93] [ True  True]
# [14 89] [14 89] [ True  True]
# [19 41] [19 41] [ True  True]
# [72 68] [72 68] [ True  True]
# [60 20] [60 20] [ True  True]
# [25 10] [25 10] [ True  True]
# [66 80] [66 80] [ True  True]
# [79 53] [79 53] [ True  True]
# [22  7] [22  7] [ True  True]
# [22 15] [22 15] [ True  True]
# [42 74] [42 74] [ True  True]
# [ 7 76] [ 7 76] [ True  True]
# [62 36] [62 36] [ True  True]
# [67 45] [67 45] [ True  True]
# [77 64] [77 64] [ True  True]
# [46 50] [46 50] [ True  True]
# [ 4 44] [ 4 44] [ True  True]
# [79 75] [79 79] [ True False]
# [21 64] [21 64] [ True  True]
# [99 27] [99 27] [ True  True]
# [83 50] [83 50] [ True  True]
# [14 21] [14 21] [ True  True]
# [96 88] [96 88] [ True  True]
# [20 93] [20 93] [ True  True]
# [83 35] [83 35] [ True  True]
# [60 64] [60 64] [ True  True]
# [52 89] [52 89] [ True  True]
# [46 90] [46 90] [ True  True]
# [17 72] [17 72] [ True  True]
# [61 19] [61 19] [ True  True]
# [40  7] [40  7] [ True  True]
# [32  0] [32  0] [ True  True]
# [86 14] [86 14] [ True  True]
# [23 88] [23 88] [ True  True]
# [17 39] [17 39] [ True  True]
# [80 15] [80 15] [ True  True]
# [19 53] [19 53] [ True  True]
# [82 37] [82 37] [ True  True]
# [79  1] [79  1] [ True  True]
# [47 82] [47 82] [ True  True]
# [61 94] [61 94] [ True  True]
# [53 65] [53 65] [ True  True]
# [90 55] [90 76] [ True False]
# [80 50] [80 50] [ True  True]
# [46  0] [46  0] [ True  True]
# [53 32] [53 32] [ True  True]
# [47 42] [47 42] [ True  True]
# [99 61] [99 61] [ True  True]
# [30 65] [30 30] [ True False]
# [ 2 74] [ 2 74] [ True  True]
# [26 70] [26 70] [ True  True]
# [73 52] [73 52] [ True  True]
# [46 11] [46 11] [ True  True]
# [45 58] [45 58] [ True  True]
# [46 48] [46 48] [ True  True]
# [67 18] [67 18] [ True  True]
# [ 3 13] [ 3 13] [ True  True]
# [70 96] [70 96] [ True  True]
# [61 24] [61 24] [ True  True]
# [33 41] [33 41] [ True  True]
# [43 49] [43 49] [ True  True]
# [90 32] [90 32] [ True  True]
# [51 91] [51 91] [ True  True]
# [36 13] [36 13] [ True  True]
# [ 5 31] [ 5 31] [ True  True]
# [34  0] [34  0] [ True  True]
# [32 24] [32 24] [ True  True]
# [76 10] [76 10] [ True  True]
# [49 40] [49 40] [ True  True]
# [64 38] [64 64] [ True False]
# [11 57] [11 57] [ True  True]
# [10  1] [10  1] [ True  True]
# [56 60] [56 60] [ True  True]
# [99 30] [99 30] [ True  True]
# [56  3] [56  3] [ True  True]
# [48 37] [48 37] [ True  True]
# [52 85] [52 85] [ True  True]
# [67 48] [67 48] [ True  True]
# [63 81] [63 81] [ True  True]
# [95 52] [95 52] [ True  True]
# [36 94] [36 94] [ True  True]
# [50 37] [50 37] [ True  True]
# [ 9 64] [ 9 64] [ True  True]
# [67 42] [67 76] [ True False]
# [59 86] [59 86] [ True  True]
# [36 13] [36 13] [ True  True]
# [18 48] [18 48] [ True  True]
# [92 12] [92 12] [ True  True]
# [78 58] [78  1] [ True False]
# [28 36] [28 36] [ True  True]
# [36 52] [36 52] [ True  True]
# [85 58] [85 58] [ True  True]
# [36 53] [36 53] [ True  True]
# [ 7 91] [ 7 91] [ True  True]
# [10 47] [10 47] [ True  True]
# [4 1] [4 1] [ True  True]
# [76 71] [76 71] [ True  True]
# [15 44] [15 44] [ True  True]
# [40 84] [40 84] [ True  True]
# [ 7 82] [ 7 82] [ True  True]
# [82 24] [82 24] [ True  True]
# [73 37] [73 37] [ True  True]
# [14 12] [14 12] [ True  True]
# [99 54] [99 54] [ True  True]
# [11 51] [11 51] [ True  True]
# [13 42] [13 42] [ True  True]
# [21 22] [21 22] [ True  True]
# [22 26] [22 26] [ True  True]
# [ 6 77] [ 6 77] [ True  True]
# [2 3] [2 3] [ True  True]
# [25 95] [25 95] [ True  True]
# [94 76] [94 76] [ True  True]
# [62 74] [62 74] [ True  True]
# [43 39] [43 39] [ True  True]
# [61  6] [61  6] [ True  True]
# [26 86] [26 86] [ True  True]
# [87 63] [87 63] [ True  True]
# [52 48] [52 48] [ True  True]
# [ 0 73] [ 0 73] [ True  True]
# [19 70] [19 70] [ True  True]
# [70 44] [70 44] [ True  True]
# [17 71] [17 71] [ True  True]
# [99 77] [99 77] [ True  True]
# [61 47] [61 47] [ True  True]
# [33  0] [33  0] [ True  True]
# [56 60] [56 60] [ True  True]
# [81 69] [81 69] [ True  True]
# [11 90] [11 90] [ True  True]
# [47 96] [47 96] [ True  True]
# [65 71] [65 71] [ True  True]
# [66 12] [66 12] [ True  True]
# [19 64] [19 64] [ True  True]
# [42  1] [42  1] [ True  True]
# [50 10] [50 10] [ True  True]
# [29 84] [29 84] [ True  True]
# [ 6 64] [ 6 64] [ True  True]
# [81 50] [81 50] [ True  True]
# [76 26] [76 26] [ True  True]
# [50 60] [50 60] [ True  True]
# [22 71] [22 71] [ True  True]
# [ 4 34] [ 4 34] [ True  True]
# [62 87] [62 62] [ True False]
# [40 61] [40 61] [ True  True]
# [39 52] [39 52] [ True  True]
# [ 9 18] [ 9 18] [ True  True]
# [63 80] [63 80] [ True  True]
# [64  0] [64  0] [ True  True]
# [88 54] [88 54] [ True  True]
# [63 10] [63 10] [ True  True]
# [83 63] [83 63] [ True  True]
# [74 47] [74 47] [ True  True]
# [ 7 80] [ 7 80] [ True  True]
# [83 81] [83 81] [ True  True]
# [59 99] [59 99] [ True  True]
# [23 47] [23 47] [ True  True]
# [77 18] [77 18] [ True  True]
# [68 62] [68 62] [ True  True]
# [25 31] [25 31] [ True  True]
# [95 18] [95 18] [ True  True]
# [62 87] [62 62] [ True False]
# [51  9] [51  9] [ True  True]
# [28 79] [28 79] [ True  True]
# [20 20] [20 20] [ True  True]
# [80 37] [80 37] [ True  True]
# [92 34] [92 34] [ True  True]
# [81 87] [81 87] [ True  True]
# [63 70] [63 70] [ True  True]
# [31 80] [31 80] [ True  True]
# [64 43] [64 43] [ True  True]
# [95 80] [95 95] [ True False]
# [83 51] [83 51] [ True  True]
# [85 58] [85 58] [ True  True]
# [39  4] [39  4] [ True  True]
# [28 94] [28 94] [ True  True]
# [70 58] [70 58] [ True  True]
# [39 77] [39 77] [ True  True]
# [10 95] [10 95] [ True  True]
# [78 20] [78 20] [ True  True]
# [61  9] [61  9] [ True  True]
# [21 62] [21 62] [ True  True]
# [85 69] [85 69] [ True  True]
# [53 85] [53 85] [ True  True]
# [64 72] [64 72] [ True  True]
# [26 66] [26 66] [ True  True]
# [30 37] [30 37] [ True  True]
# [77 99] [77 99] [ True  True]
# [54 69] [54 69] [ True  True]
# [51 15] [51 15] [ True  True]
# [ 5 80] [ 5 80] [ True  True]
# [28 27] [28 27] [ True  True]
# [28 32] [28 32] [ True  True]
# [55 52] [55 52] [ True  True]
# [31 37] [31 37] [ True  True]
# [25 44] [25 44] [ True  True]
# [17 87] [17 87] [ True  True]
# [70 75] [70 75] [ True  True]
# [67 48] [67 48] [ True  True]
# [28 23] [28 23] [ True  True]
# [68 75] [68 75] [ True  True]
# [48 91] [48 91] [ True  True]
# [64 54] [64 54] [ True  True]
# [18 80] [18 80] [ True  True]
# [64 75] [64 75] [ True  True]
# [70  8] [70  8] [ True  True]
# [40 73] [40 73] [ True  True]
# [18 24] [18 24] [ True  True]
# [50 80] [50 80] [ True  True]
# [67  2] [67  2] [ True  True]
# [78 25] [78 25] [ True  True]
# [89 80] [89 80] [ True  True]
# [91 56] [91 56] [ True  True]
# [13 25] [13 86] [ True False]
# [90 16] [90 16] [ True  True]
# [91 67] [91 67] [ True  True]
# [59 63] [59 63] [ True  True]
# [36 28] [36 28] [ True  True]
# [97  6] [97  6] [ True  True]
# [45 42] [45 42] [ True  True]
# [10 91] [10 91] [ True  True]
# [23 92] [23 92] [ True  True]
# [ 3 63] [ 3 63] [ True  True]
# [68 95] [68 95] [ True  True]
# [42 59] [42 59] [ True  True]
# [66 68] [66 68] [ True  True]
# [39 22] [39 22] [ True  True]
# [71 17] [71 22] [ True False]
# [20 82] [20 82] [ True  True]
# [30  6] [30  6] [ True  True]
# [86 58] [86 58] [ True  True]
# [76 36] [76 36] [ True  True]
# [12 60] [12 60] [ True  True]
# [45 59] [45 59] [ True  True]
# [45  6] [45  6] [ True  True]
# [42 52] [42 52] [ True  True]
# [32 63] [32 63] [ True  True]
# [51 96] [51 96] [ True  True]
# [51 14] [51 14] [ True  True]
# [11 69] [11 69] [ True  True]
# [71 22] [71 22] [ True  True]
# [71 58] [71 58] [ True  True]
# [19 97] [19 97] [ True  True]
# [65 79] [65 79] [ True  True]
# [50 72] [50 72] [ True  True]
# [82 55] [82 55] [ True  True]
# [51 56] [51 56] [ True  True]
# [15  4] [15  4] [ True  True]
# [87 27] [87 27] [ True  True]
# [ 9 10] [ 9 10] [ True  True]
# [21 99] [21 99] [ True  True]
# [67 55] [67 55] [ True  True]
# [20 97] [20 97] [ True  True]
# [98 10] [98 10] [ True  True]
# [76 87] [76 87] [ True  True]
# [97 70] [97 70] [ True  True]
# [72 76] [72 76] [ True  True]
# [85  7] [85  7] [ True  True]
# [43 59] [43 59] [ True  True]
# [46 88] [46 46] [ True False]
# [98  8] [98  8] [ True  True]
# [15 66] [15 66] [ True  True]
# [92 45] [92 66] [ True False]
# [58 64] [58 64] [ True  True]
# [21 32] [21 32] [ True  True]
# [49 79] [49 79] [ True  True]
# [30 71] [30 71] [ True  True]
# [70 60] [70 60] [ True  True]
# [48 68] [48 68] [ True  True]
# [97 17] [97 17] [ True  True]
# [97 51] [97 51] [ True  True]
# [38 86] [38 86] [ True  True]
# [73 89] [73 73] [ True False]
# [83 74] [83 74] [ True  True]
# [57 41] [57 41] [ True  True]
# [71 22] [71 22] [ True  True]
# [28  7] [28  7] [ True  True]
# [97 79] [97 79] [ True  True]
# [54 34] [54 34] [ True  True]
# [ 7 71] [ 7 71] [ True  True]
# [47 53] [47 53] [ True  True]
# [67 65] [67 65] [ True  True]
# [25 71] [25 71] [ True  True]
# [33 68] [33 68] [ True  True]
# [55 32] [55 32] [ True  True]
# [45 22] [45 22] [ True  True]
# [38 19] [38 19] [ True  True]
# [19 41] [19 41] [ True  True]
# [99 80] [99 80] [ True  True]
# [78 37] [78 37] [ True  True]
# [49 82] [49 82] [ True  True]
# [57 64] [57 64] [ True  True]
# [48 69] [48 69] [ True  True]
# [76 79] [76 79] [ True  True]
# [26 17] [26 17] [ True  True]
# [23 19] [23 19] [ True  True]
# [80 53] [80 53] [ True  True]
# [82 85] [82 85] [ True  True]
# [60 29] [60 29] [ True  True]
# [24 17] [24 17] [ True  True]
# [75 49] [75 49] [ True  True]
# [55 20] [55 20] [ True  True]
# [74 14] [74 14] [ True  True]
# [15 66] [15 66] [ True  True]
# [33 39] [33 49] [ True False]
# [85 41] [85 41] [ True  True]
# [73 20] [73 20] [ True  True]
# [25 27] [25 27] [ True  True]
# [0 8] [0 8] [ True  True]
# [52 82] [52 82] [ True  True]
# [36 75] [36 75] [ True  True]
# [50 13] [50 13] [ True  True]
# [11 64] [11 64] [ True  True]
# [23  9] [23 23] [ True False]
# [94 10] [94 10] [ True  True]
# [68 20] [68 20] [ True  True]
# [99 45] [99 45] [ True  True]
# [88 79] [88 79] [ True  True]
# [54 47] [54 47] [ True  True]
# [29  4] [29  4] [ True  True]
# [11 55] [11 55] [ True  True]
# [26 65] [26 65] [ True  True]
# [38 29] [38 29] [ True  True]
# [52 63] [52 63] [ True  True]
# [39 28] [39 28] [ True  True]
# [64 87] [64 87] [ True  True]
# [15 81] [15 81] [ True  True]
# [41 25] [41 25] [ True  True]
# [34 82] [34 82] [ True  True]
# [55 48] [55 48] [ True  True]
# [37 46] [37 46] [ True  True]
# [69 31] [69 31] [ True  True]
# [28 78] [28 78] [ True  True]
# [75 46] [75 46] [ True  True]
# [62 30] [62 30] [ True  True]
# [91 78] [91 78] [ True  True]
# [60 22] [60 22] [ True  True]
# [69 68] [69 68] [ True  True]
# [ 7 64] [ 7 64] [ True  True]
# [44 54] [44 54] [ True  True]
# [58 36] [58 36] [ True  True]
# [38 27] [38 27] [ True  True]
# [15 90] [15 90] [ True  True]
# [59 99] [59 99] [ True  True]
# [83 25] [83 25] [ True  True]
# [21 14] [21 14] [ True  True]
# [74  5] [74  5] [ True  True]
# [79 33] [79 33] [ True  True]
# [38 31] [38 31] [ True  True]
# [ 0 62] [ 0 62] [ True  True]
# [11 71] [11 71] [ True  True]
# [61 27] [61 27] [ True  True]
# [69 88] [69 88] [ True  True]
# [87 65] [87 65] [ True  True]
# [61 21] [61 61] [ True False]
# [64 15] [64 15] [ True  True]
# [63 54] [63 54] [ True  True]
# [42 84] [42 84] [ True  True]
# [94 96] [94 96] [ True  True]
# [77 93] [77 93] [ True  True]
# [71 14] [71 14] [ True  True]
# [ 5 25] [ 5 25] [ True  True]
# [ 8 58] [ 8 58] [ True  True]
# [49 70] [49 70] [ True  True]
# [57 60] [57 57] [ True False]
# [56 51] [56 51] [ True  True]
# [61 98] [61 98] [ True  True]
# [38 61] [38 61] [ True  True]
# [91 82] [91 24] [ True False]
# [42  7] [42  7] [ True  True]
# [12 40] [12 40] [ True  True]
# [25 53] [25 53] [ True  True]
# [17 97] [17 97] [ True  True]
# [80 57] [80 57] [ True  True]
# [53 62] [53 62] [ True  True]
# [ 0 32] [ 0 32] [ True  True]
# [ 9 38] [ 9 27] [ True False]
# [17  4] [17  4] [ True  True]
# [88 49] [88 49] [ True  True]
# [ 6 69] [ 6 69] [ True  True]
# [35 88] [35 88] [ True  True]
# [68 18] [68 18] [ True  True]
# [21 47] [21 47] [ True  True]
# [40 89] [40 89] [ True  True]
# [78 48] [78 48] [ True  True]
# [57  4] [57  4] [ True  True]
# [72 73] [72 73] [ True  True]
# [63 71] [63 71] [ True  True]
# [45 55] [45 55] [ True  True]
# [46 91] [46 91] [ True  True]
# [42 19] [42 19] [ True  True]
# [79 84] [79 84] [ True  True]
# [84 79] [84 79] [ True  True]
# [95  3] [95  3] [ True  True]
# [ 8 67] [ 8 67] [ True  True]
# [ 4 92] [ 4 92] [ True  True]
# [43 42] [43 42] [ True  True]
# [85 34] [85 34] [ True  True]
# [68 49] [68 49] [ True  True]
# [59 32] [59 32] [ True  True]
# [91 29] [91 29] [ True  True]
# [99 18] [99 18] [ True  True]
# [82  6] [82  6] [ True  True]
# [98 33] [98 33] [ True  True]
# [35 17] [35 35] [ True False]
# [13  1] [13  1] [ True  True]
# [13 88] [13 88] [ True  True]
# [55  9] [55  9] [ True  True]
# [32 76] [32 76] [ True  True]
# [59 88] [59 59] [ True False]
# [33 59] [33 33] [ True False]
# [83 96] [83 96] [ True  True]
# [60 24] [60 24] [ True  True]
# [13  8] [13  8] [ True  True]
# [70 58] [70 58] [ True  True]
# [46 15] [46 15] [ True  True]
# [45 55] [45 55] [ True  True]
# [42  7] [42  7] [ True  True]
# [18 77] [18 77] [ True  True]
# [28 67] [28 67] [ True  True]
# [84 93] [84 93] [ True  True]
# [44 79] [44 79] [ True  True]
# [57 93] [57 93] [ True  True]
# [60  3] [60  3] [ True  True]
# [52 56] [52 52] [ True False]
# [52 83] [52 83] [ True  True]
# [89  6] [89  6] [ True  True]
# [91 34] [91 34] [ True  True]
# [16 74] [16 74] [ True  True]
# [90 90] [90 90] [ True  True]
# [ 1 98] [ 1 98] [ True  True]
# [62 63] [62 63] [ True  True]
# [65 58] [65 58] [ True  True]
# [58 33] [58 33] [ True  True]
# [76 99] [76 99] [ True  True]
# [58 34] [58 34] [ True  True]
# [96 50] [96 50] [ True  True]
# [89 29] [89 29] [ True  True]
# [80 27] [80 27] [ True  True]
# [18 29] [18 29] [ True  True]
# [86 23] [86 23] [ True  True]
# [ 8 70] [ 8 70] [ True  True]
# [90 26] [90 26] [ True  True]
# [67 47] [67 47] [ True  True]
# [96 50] [96 50] [ True  True]
# [75 60] [75 60] [ True  True]
# [78 33] [78 33] [ True  True]
# [22 90] [22 90] [ True  True]
# [80 15] [80 15] [ True  True]
# [72 64] [72 64] [ True  True]
# [86 46] [86 46] [ True  True]
# [72 65] [72 65] [ True  True]
# [81 48] [81 48] [ True  True]
# [10 61] [10 61] [ True  True]
# [30 37] [30 37] [ True  True]
# [30 78] [30 78] [ True  True]
# [91 45] [91 45] [ True  True]
# [ 0 25] [ 0 25] [ True  True]
# [11 76] [11 76] [ True  True]
# [57 77] [57 77] [ True  True]
# [ 6 36] [ 6 36] [ True  True]
# [53 57] [53 57] [ True  True]
# [ 1 27] [ 1 27] [ True  True]
# [54 23] [54 23] [ True  True]
# [85 22] [85 22] [ True  True]
# [41 94] [41 94] [ True  True]
# [25 44] [25 44] [ True  True]
# [76 79] [76 79] [ True  True]
# [11 24] [11 24] [ True  True]
# [67 51] [67 51] [ True  True]
# [74  6] [74  6] [ True  True]
# [55 94] [55 94] [ True  True]
# [16 54] [16 54] [ True  True]
# [49 45] [49 45] [ True  True]
# [83  2] [83  2] [ True  True]
# [98 51] [98 51] [ True  True]
# [ 2 21] [ 2 21] [ True  True]
# [30 11] [30 11] [ True  True]
# [62 42] [62 42] [ True  True]
# [75 27] [75 27] [ True  True]
# [ 7 79] [ 7 79] [ True  True]
# [ 1 64] [ 1 64] [ True  True]
# [17 66] [17 66] [ True  True]
# [58 97] [58 97] [ True  True]
# [68 88] [68 88] [ True  True]
# [93 27] [93 27] [ True  True]
# [35 29] [35 29] [ True  True]
# [77 30] [77 30] [ True  True]
# [ 9 56] [ 9 56] [ True  True]
# [80 36] [80 36] [ True  True]
# [60 59] [60 59] [ True  True]
# [99 13] [99 13] [ True  True]
# [65 30] [65 30] [ True  True]
# [66 17] [66 17] [ True  True]
# [ 2 54] [ 2 54] [ True  True]
# [86 36] [86 36] [ True  True]
# [37 51] [37 37] [ True False]
# [16  8] [16  8] [ True  True]
# [32 19] [32 19] [ True  True]
# [35 99] [35 99] [ True  True]
# [28 25] [28 81] [ True False]
# [38 14] [38 14] [ True  True]
# [99 31] [99 31] [ True  True]
# [36 92] [36 92] [ True  True]
# [16 76] [16 76] [ True  True]
# [75 64] [75 64] [ True  True]
# [50 79] [50 79] [ True  True]
# [58 45] [58 45] [ True  True]
# [51 40] [51 40] [ True  True]
# [34 89] [34 89] [ True  True]
# [37 40] [37 40] [ True  True]
# [75 17] [75 17] [ True  True]
# [ 0 42] [ 0 42] [ True  True]
# [93 56] [93 56] [ True  True]
# [33 66] [33 66] [ True  True]
# [19 86] [19 86] [ True  True]
# [24 34] [24 34] [ True  True]
# [2 0] [2 0] [ True  True]
# [28 58] [28 58] [ True  True]
# [44 88] [44 88] [ True  True]
# [64 25] [64 25] [ True  True]
# [87 27] [87 27] [ True  True]
# [34 78] [34 78] [ True  True]
# [43 10] [43 10] [ True  True]
# [19  6] [19  6] [ True  True]
# [42 77] [42 77] [ True  True]
# [24  5] [24  5] [ True  True]
# [ 0 66] [ 0 66] [ True  True]
# [31  4] [31  4] [ True  True]
# [90 80] [90 80] [ True  True]
# [72  2] [72  2] [ True  True]
# [29  7] [29  7] [ True  True]
# [21 59] [21 59] [ True  True]
# [85 30] [85 30] [ True  True]
# [30 49] [30 49] [ True  True]
# [23 13] [23 13] [ True  True]
# [57 75] [57 75] [ True  True]
# [47 32] [47 32] [ True  True]
# [11 24] [11 24] [ True  True]
# [56 93] [56 93] [ True  True]
# [60  3] [60  3] [ True  True]
# [65 86] [65 86] [ True  True]
# [79 23] [79 23] [ True  True]
# [52 24] [52 24] [ True  True]
# [38 22] [38 22] [ True  True]
# [43 23] [43 23] [ True  True]
# [39 60] [39 60] [ True  True]
# [17 98] [17 98] [ True  True]
# [ 9 42] [9 9] [ True False]
# [82 91] [82 62] [ True False]
# [67 57] [67 57] [ True  True]
# [76 39] [76 39] [ True  True]
# [58 22] [58 22] [ True  True]
# [66 55] [66 55] [ True  True]
# [93  1] [93  1] [ True  True]
# [99 65] [99 65] [ True  True]
# [50 77] [50 77] [ True  True]
# [20 75] [20 75] [ True  True]
# [16  6] [16  6] [ True  True]
# [29 61] [29 29] [ True False]
# [56 50] [56 50] [ True  True]
# [90 85] [90 85] [ True  True]
# [ 5 88] [ 5 88] [ True  True]
# [ 9 64] [ 9 64] [ True  True]
# [26 46] [26 46] [ True  True]
# [63 46] [63 46] [ True  True]
# [92 73] [92 73] [ True  True]
# [69 39] [69 39] [ True  True]
# [62  8] [62  8] [ True  True]
# [72 90] [72 90] [ True  True]
# [12 95] [12 95] [ True  True]
# [12 92] [12 92] [ True  True]
# [35 22] [35 22] [ True  True]
# [42 53] [42 53] [ True  True]
# [28 75] [28 75] [ True  True]
# [18 40] [18 18] [ True False]
# [69 10] [69 10] [ True  True]
# [37  7] [37  7] [ True  True]
# [20  4] [20  4] [ True  True]
# [28 42] [28 42] [ True  True]
# [46 57] [46 46] [ True False]
# [27 66] [27 66] [ True  True]
# [23 30] [23 30] [ True  True]
# [60  3] [60  3] [ True  True]
# [68 71] [68 71] [ True  True]
# [53 42] [53 42] [ True  True]
# [11 37] [11 37] [ True  True]
# [69 86] [69 86] [ True  True]
# [53 39] [53 39] [ True  True]
# [44 60] [44 60] [ True  True]
# [58  9] [58  9] [ True  True]
# [76 77] [76 77] [ True  True]
# [40 38] [40 38] [ True  True]
# [15 47] [15 47] [ True  True]
# [77  9] [77  9] [ True  True]
# [ 8 19] [ 8 19] [ True  True]
# [26 55] [26 55] [ True  True]
# [11 82] [11 82] [ True  True]
# [93 99] [93 99] [ True  True]
# [23 50] [23 50] [ True  True]
# [30 38] [30 38] [ True  True]
# [44 97] [44 97] [ True  True]
# [86 93] [86 93] [ True  True]
# [86 70] [86 70] [ True  True]
# [75 70] [75 70] [ True  True]
# [76 88] [76 88] [ True  True]
# [68 54] [68 54] [ True  True]
# [57  8] [57  8] [ True  True]
# [33 69] [33 69] [ True  True]
# [93 74] [93 74] [ True  True]
# [56 85] [56 85] [ True  True]
# [44 58] [44 58] [ True  True]
# [53 55] [53 55] [ True  True]
# [47 68] [47 68] [ True  True]
# [98 48] [98 48] [ True  True]
# [80 81] [80 81] [ True  True]
# [83 41] [83 41] [ True  True]
# [62 47] [62 47] [ True  True]
# [98  1] [98 39] [ True False]
# [10 10] [10 10] [ True  True]
# [25 37] [25 37] [ True  True]
# [22 10] [22 10] [ True  True]
# [25 12] [25 12] [ True  True]
# [79 75] [79 75] [ True  True]
# [66 49] [66 49] [ True  True]
# [46 37] [46 37] [ True  True]
# [28 45] [28 45] [ True  True]
# [70 32] [70 32] [ True  True]
# [70  9] [70  9] [ True  True]
# [81 84] [81 84] [ True  True]
# [51 13] [51 13] [ True  True]
# [65 59] [65 59] [ True  True]
# [30 81] [30 81] [ True  True]
# [85 61] [85 92] [ True False]
# [83 30] [83 30] [ True  True]
# [73  3] [73  3] [ True  True]
# [ 1 35] [ 1 35] [ True  True]
# [29 94] [29 94] [ True  True]
# [39 67] [39 67] [ True  True]
# [47 10] [47 47] [ True False]
# [89  1] [89  1] [ True  True]
# [71 88] [71 88] [ True  True]
# [16 54] [16 54] [ True  True]
# [71 80] [71 80] [ True  True]
# [ 8 39] [ 8 39] [ True  True]
# [8 8] [8 8] [ True  True]
# [62 63] [62 63] [ True  True]
# [45 77] [45 77] [ True  True]
# [ 3 90] [ 3 90] [ True  True]
# [93 70] [93 70] [ True  True]
# [74 19] [74 19] [ True  True]
# [36 13] [36 13] [ True  True]
# [65 21] [65 21] [ True  True]
# [15 63] [15 63] [ True  True]
# [74 79] [74 79] [ True  True]
# [56  2] [56  2] [ True  True]
# [13  0] [13  0] [ True  True]
# [70 77] [70 77] [ True  True]
# [90 24] [90 24] [ True  True]
# [60  7] [60  7] [ True  True]
# [41 77] [41 77] [ True  True]
# [74 25] [74 25] [ True  True]
# [36  1] [36 36] [ True False]
# [98 18] [98 18] [ True  True]
# [20 41] [20 41] [ True  True]
# [55 94] [55 94] [ True  True]
# [48 52] [48 52] [ True  True]
# [58 92] [58 92] [ True  True]
# [50 84] [50 84] [ True  True]
# [30 19] [30 19] [ True  True]
# [61 37] [61 61] [ True False]
# [98  8] [98  8] [ True  True]
# [90 78] [90 78] [ True  True]
# [34 22] [34 22] [ True  True]
# [75 71] [75 71] [ True  True]
# [ 3 18] [ 3 18] [ True  True]
# [75 47] [75 47] [ True  True]
# [74 20] [74 20] [ True  True]
# [41 15] [41 15] [ True  True]
# [44 76] [44 76] [ True  True]
# [59 16] [59 16] [ True  True]
# [55  0] [55  0] [ True  True]
# [79 25] [79 79] [ True False]
# [98 82] [98 82] [ True  True]
# [83 43] [83 43] [ True  True]
# [27 66] [27 66] [ True  True]
# [32 70] [32 70] [ True  True]
# [92 76] [92 76] [ True  True]
# [21  6] [21  6] [ True  True]
# [66 84] [66 84] [ True  True]
# [56 49] [56 49] [ True  True]
# [51 82] [51 82] [ True  True]
# [89 79] [89 79] [ True  True]
# [79 13] [79 13] [ True  True]
# [18 84] [18 84] [ True  True]
# [11 14] [11 14] [ True  True]
# [35 41] [35 41] [ True  True]
# [88 97] [88 97] [ True  True]
# [59 56] [59 56] [ True  True]
# [14 89] [14 89] [ True  True]
# [26 15] [26 15] [ True  True]
# [14 75] [14 75] [ True  True]
# [10  1] [10  1] [ True  True]
# [66 90] [66 90] [ True  True]
# [81 48] [81 48] [ True  True]
# [44 80] [44 80] [ True  True]
# [98 13] [98 13] [ True  True]
# [27 42] [27 42] [ True  True]
# [76 45] [76 45] [ True  True]
# [56  9] [56  9] [ True  True]
# [95 53] [95 53] [ True  True]
# [88 79] [88 79] [ True  True]
# [45 22] [45 22] [ True  True]
# [ 8 64] [ 8 64] [ True  True]
# [94 65] [94 65] [ True  True]
# [97 21] [97 21] [ True  True]
# [84 26] [84 26] [ True  True]
# [48 44] [48 44] [ True  True]
# [95 46] [95 46] [ True  True]
# [11 46] [11 46] [ True  True]
# [20 86] [20 86] [ True  True]
# [91 73] [91 73] [ True  True]
# [95 26] [95 26] [ True  True]
# [52 58] [52 58] [ True  True]
# [11 25] [11 25] [ True  True]
# [97 14] [97 14] [ True  True]
# [45 69] [45 69] [ True  True]
# [ 5 49] [ 5 49] [ True  True]
# [52 66] [52 66] [ True  True]
# [84 23] [84 23] [ True  True]
# [26 84] [26 84] [ True  True]
# [40 82] [40 40] [ True False]
# [ 3 19] [ 3 19] [ True  True]
# [11 74] [11 74] [ True  True]
# [98 30] [98 30] [ True  True]
# [11 87] [11 87] [ True  True]
# [10 92] [10 92] [ True  True]
# [95 67] [95 67] [ True  True]
# [19 96] [19 96] [ True  True]
# [69 38] [69 38] [ True  True]
# [89 80] [89 80] [ True  True]
# [12 51] [12 51] [ True  True]
# [96 14] [96 14] [ True  True]
# [86 55] [86 55] [ True  True]
# [54 34] [54 34] [ True  True]
# [27 35] [27 35] [ True  True]
# [46 16] [46 49] [ True False]
# [75 34] [75 34] [ True  True]
# [94 64] [94 64] [ True  True]
# [74 21] [74 21] [ True  True]
# [85 23] [85 23] [ True  True]
# [ 1 10] [ 1 10] [ True  True]
# [79  0] [79  0] [ True  True]
# [66 72] [66 72] [ True  True]
# [28 10] [28 10] [ True  True]
# [75 92] [75 92] [ True  True]
# [85 26] [85 26] [ True  True]
# [89 54] [89 54] [ True  True]
# [54 85] [54 85] [ True  True]
# [73  6] [73  6] [ True  True]
# [92 99] [92 99] [ True  True]
# [52 84] [52 84] [ True  True]
# [39 21] [39 21] [ True  True]
# [64 95] [64 95] [ True  True]
# [ 1 91] [ 1 91] [ True  True]
# [15 55] [15 55] [ True  True]
# [89 88] [89 88] [ True  True]
# [22 95] [22 95] [ True  True]
# [11 71] [11 11] [ True False]
# [74 25] [74 25] [ True  True]
# [14 16] [14 16] [ True  True]
# [98 56] [98 56] [ True  True]
# [10 10] [10 10] [ True  True]
# [14 55] [14 55] [ True  True]
# [26 14] [26 14] [ True  True]
# [44  6] [44  6] [ True  True]
# [95 49] [95 49] [ True  True]
# [87  9] [87  9] [ True  True]
# [21 59] [21 59] [ True  True]
# [23 74] [23 74] [ True  True]
# [76 47] [76 47] [ True  True]
# [9 4] [9 4] [ True  True]
# [ 8 99] [ 8 99] [ True  True]
# [29 81] [29 81] [ True  True]
# [17 78] [17 78] [ True  True]
# [29 37] [29 37] [ True  True]
# [96 64] [96 64] [ True  True]
# [41 11] [41 11] [ True  True]
# [62  7] [62  7] [ True  True]
# [90 93] [90 73] [ True False]
# [78 84] [78 84] [ True  True]
# [36 83] [36 83] [ True  True]
# [41 35] [41 35] [ True  True]
# [ 5 57] [ 5 57] [ True  True]
# [93 61] [93 61] [ True  True]
# [34 44] [34 44] [ True  True]
# [28 34] [28 34] [ True  True]
# [ 0 87] [ 0 87] [ True  True]
# [ 7 81] [ 7 81] [ True  True]
# [51 25] [51 25] [ True  True]
# [46 14] [46 14] [ True  True]
# [28 53] [28 53] [ True  True]
# [24 87] [24 87] [ True  True]
# [56 35] [56 35] [ True  True]
# [61 50] [61 50] [ True  True]
# [ 6 18] [ 6 18] [ True  True]
# [45 61] [45 61] [ True  True]
# [14 31] [14 31] [ True  True]
# [91 27] [91 27] [ True  True]
# [86 96] [86 96] [ True  True]
# [49 24] [49 24] [ True  True]
# [27 26] [27 26] [ True  True]
# [12 35] [12 35] [ True  True]
# [74 92] [74 92] [ True  True]
# [48 52] [48 52] [ True  True]
# [59 85] [59 85] [ True  True]
# [65 95] [65 95] [ True  True]
# [31 16] [31 31] [ True False]
# [21 35] [21 35] [ True  True]
# [16 90] [16 90] [ True  True]
# [46 28] [46 28] [ True  True]
# [11 96] [11 96] [ True  True]
# [38 35] [38 35] [ True  True]
# [76 99] [76 99] [ True  True]
# [23 59] [23 59] [ True  True]
# [69 29] [69 29] [ True  True]
# [38 42] [38 42] [ True  True]
# [ 4 79] [ 4 79] [ True  True]
# [86  9] [86  9] [ True  True]
# [ 1 34] [ 1 34] [ True  True]
# [64 75] [64 75] [ True  True]
# [21 39] [21 39] [ True  True]
# [13 28] [13 28] [ True  True]
# [24 43] [24 43] [ True  True]
# [91 60] [91 91] [ True False]
# [13 14] [13 14] [ True  True]
# [ 5 13] [ 5 13] [ True  True]
# [36 69] [36 69] [ True  True]
# [90 59] [90 59] [ True  True]
# [70  2] [70  2] [ True  True]
# [ 1 62] [ 1 34] [ True False]
# [20 68] [20 68] [ True  True]
# [23 99] [23 99] [ True  True]
# [41 92] [41 41] [ True False]
# [44  1] [44  1] [ True  True]
# [38 11] [38 11] [ True  True]
# [74 49] [74 49] [ True  True]
# [94 86] [94 86] [ True  True]
# [90 59] [90 59] [ True  True]
# [98 88] [98 88] [ True  True]
# [27 54] [27 54] [ True  True]
# [51 33] [51 33] [ True  True]
# [30  0] [30  0] [ True  True]
# [17  2] [17  2] [ True  True]
# [72 36] [72 36] [ True  True]
# [56 52] [56 52] [ True  True]
# [41  8] [41  8] [ True  True]
# [71 59] [71 59] [ True  True]
# [66 56] [66 56] [ True  True]
# [ 0 79] [ 0 79] [ True  True]
# [52 47] [52 47] [ True  True]
# [95 21] [95 21] [ True  True]
# [82 66] [82 66] [ True  True]
# [83 87] [83 83] [ True False]
# [68 17] [68 17] [ True  True]
# [72 87] [72 87] [ True  True]
# [81 67] [81 67] [ True  True]
# [66 40] [66 40] [ True  True]
# [74 29] [74 29] [ True  True]
# [55 65] [55 65] [ True  True]
# [34 73] [34 73] [ True  True]
# [93 98] [93 98] [ True  True]
# [34 68] [34 68] [ True  True]
# [81 19] [81 19] [ True  True]
# [39 98] [39 98] [ True  True]
# [34 13] [34 13] [ True  True]
# [55 68] [55 68] [ True  True]
# [85 86] [85 86] [ True  True]
# [80 27] [80 27] [ True  True]
# [56 55] [56 55] [ True  True]
# [27 11] [27 11] [ True  True]
# [39 63] [39 63] [ True  True]
# [ 0 17] [ 0 17] [ True  True]
# [43 89] [43 89] [ True  True]
# [85 34] [85 34] [ True  True]
# [52 16] [52 52] [ True False]
# [37 51] [37 51] [ True  True]
# [32 61] [32 61] [ True  True]
# [ 7 95] [ 7 95] [ True  True]
# [91 11] [91 11] [ True  True]
# [54 78] [54 78] [ True  True]
# [23 59] [23 59] [ True  True]
# [ 7 89] [ 7 89] [ True  True]
# [77 59] [77 59] [ True  True]
# [77 85] [77 85] [ True  True]
# [36 14] [36 14] [ True  True]
# [64 35] [64 35] [ True  True]
# [76 37] [76 37] [ True  True]
# [49 89] [49 89] [ True  True]
# [ 0 67] [ 0 67] [ True  True]
# [68 21] [68 21] [ True  True]
# [84 69] [84 69] [ True  True]
# [40 83] [40 83] [ True  True]
# [83 54] [83 54] [ True  True]
# [78 38] [78 38] [ True  True]
# [48 43] [48 43] [ True  True]
# [42 26] [42 26] [ True  True]
# [65 83] [65 83] [ True  True]
# [59 46] [59 46] [ True  True]
# [26 33] [26 33] [ True  True]
# [77 55] [77 55] [ True  True]
# [63 88] [63 88] [ True  True]
# [36 35] [36 35] [ True  True]
# [34 93] [34 93] [ True  True]
# [48 48] [48 48] [ True  True]
# [29 71] [29 71] [ True  True]
# [99 47] [99 47] [ True  True]
# [81 64] [81 64] [ True  True]
# [76 60] [76 60] [ True  True]
# [80 30] [80 30] [ True  True]
# [86  3] [86  3] [ True  True]
# [53 62] [53 62] [ True  True]
# [90 43] [90 43] [ True  True]
# [50 64] [50 64] [ True  True]
# [44 92] [44 92] [ True  True]
# [52 40] [52 40] [ True  True]
# [48 46] [48 46] [ True  True]
# [25 31] [25 31] [ True  True]
# [95 72] [95 72] [ True  True]
# [57 24] [57 24] [ True  True]
# [33 79] [33 79] [ True  True]
# [79 64] [79 64] [ True  True]
# [38 48] [38 48] [ True  True]
# [79 51] [79 51] [ True  True]
# [ 4 66] [ 4 66] [ True  True]
# [13  9] [13  9] [ True  True]
# [ 4 44] [ 4 44] [ True  True]
# [30 42] [30 42] [ True  True]
# [20 63] [20 63] [ True  True]
# [75  1] [75  1] [ True  True]
# [58 20] [58 58] [ True False]
# [ 9 61] [ 9 61] [ True  True]
# [66 17] [66 17] [ True  True]
# [49 90] [49 90] [ True  True]
# [17 70] [17 70] [ True  True]
# [ 4 37] [ 4 51] [ True False]
# [18 67] [18 67] [ True  True]
# [88 30] [88 30] [ True  True]
# [77 74] [77 74] [ True  True]
# [61 85] [61 85] [ True  True]
# [82  3] [82  3] [ True  True]
# [ 8 20] [ 8 20] [ True  True]
# [81 13] [81 13] [ True  True]
# [73 12] [73 12] [ True  True]
# [14  4] [14  4] [ True  True]
# [89 50] [89 50] [ True  True]
# [16 31] [16 31] [ True  True]
# [37 11] [37 37] [ True False]
# [51 47] [51 47] [ True  True]
# [20 71] [20 71] [ True  True]
# [56 16] [56 16] [ True  True]
# [70  6] [70  6] [ True  True]
# [32 69] [32 69] [ True  True]
# [ 3 34] [ 3 34] [ True  True]
# [ 4 47] [ 4 47] [ True  True]
# [16 88] [16 19] [ True False]
# [60 73] [60 73] [ True  True]
# [23 31] [23 31] [ True  True]
# [16 31] [16 31] [ True  True]
# [74 61] [74 61] [ True  True]
# [32 12] [32 12] [ True  True]
# [60 48] [60 48] [ True  True]
# [54 58] [54 58] [ True  True]
# [81 26] [81 26] [ True  True]
# [67 79] [67 79] [ True  True]
# [86 67] [86 67] [ True  True]
# [34 32] [34 34] [ True False]
# [59  3] [59  3] [ True  True]
# [94 53] [94 53] [ True  True]
# [37 29] [37 29] [ True  True]
# [17 18] [17 18] [ True  True]
# [37 46] [37 46] [ True  True]
# [31 31] [31 31] [ True  True]
# [64 73] [64 73] [ True  True]
# [66 83] [66 83] [ True  True]
# [73 60] [73 60] [ True  True]
# [38 97] [38 97] [ True  True]
# [91 45] [91 45] [ True  True]
# [42 20] [42 20] [ True  True]
# [ 8 49] [ 8 49] [ True  True]
# [20 23] [20 23] [ True  True]
# [26 31] [26 31] [ True  True]
# [92 76] [92 76] [ True  True]
# [30 41] [30 41] [ True  True]
# [ 4 16] [ 4 16] [ True  True]
# [40 62] [40 62] [ True  True]
# [85 37] [85 37] [ True  True]
# [32 13] [32 13] [ True  True]
# [93 32] [93 32] [ True  True]
# [83 12] [83 12] [ True  True]
# [11 10] [11 10] [ True  True]
# [60 79] [60 79] [ True  True]
# [44  1] [44  1] [ True  True]
# [45 47] [45 47] [ True  True]
# [99 81] [99 81] [ True  True]
# [20 63] [20 63] [ True  True]
# [95 33] [95 33] [ True  True]
# [96 89] [96 89] [ True  True]
# [43 24] [43 24] [ True  True]
# [64 37] [64 37] [ True  True]
# [48 34] [48 34] [ True  True]
# [ 0 28] [ 0 28] [ True  True]
# [33 92] [33 92] [ True  True]
# [72 55] [72 55] [ True  True]
# [34  8] [34  8] [ True  True]
# [25 42] [25 42] [ True  True]
# [90 17] [90 17] [ True  True]
# [20 88] [20 88] [ True  True]
# [ 8 19] [ 8 19] [ True  True]
# [25 30] [25 30] [ True  True]
# [29 51] [29 51] [ True  True]
# [73 15] [73 15] [ True  True]
# [82 79] [82 79] [ True  True]
# [11 63] [11 63] [ True  True]
# [85 36] [85 36] [ True  True]
# [42 66] [42 66] [ True  True]
# [22 86] [22 86] [ True  True]
# [15 79] [15 79] [ True  True]
# [21 81] [21 81] [ True  True]
# [46 58] [46 58] [ True  True]
# [55 56] [55 56] [ True  True]
# [58 52] [58 52] [ True  True]
# [35 19] [35 19] [ True  True]
# [45 19] [45 19] [ True  True]
# [ 2 93] [ 2 93] [ True  True]
# [42 96] [42 96] [ True  True]
# [11 59] [11 59] [ True  True]
# [80  7] [80  0] [ True False]
# [44 11] [44 11] [ True  True]
# [11 14] [11 14] [ True  True]
# [99 48] [99 48] [ True  True]
# [93 92] [93 92] [ True  True]
# [17 57] [17 57] [ True  True]
# [59 24] [59 24] [ True  True]
# [ 7 45] [ 7 45] [ True  True]
# [78 12] [78 12] [ True  True]
# [40  4] [40  4] [ True  True]
# [65 81] [65 81] [ True  True]
# [83 19] [83 19] [ True  True]
# [10 74] [10 74] [ True  True]
# [62 56] [62 56] [ True  True]
# [ 9 31] [ 9 31] [ True  True]
# [76 67] [76 67] [ True  True]
# [84 17] [84 17] [ True  True]
# [59 78] [59 78] [ True  True]
# [12 41] [12 41] [ True  True]
# [67 31] [67 31] [ True  True]
# [41 64] [41 64] [ True  True]
# [49 16] [49 16] [ True  True]
# [74 70] [74 70] [ True  True]
# [42 90] [42 90] [ True  True]
# [39 49] [39 49] [ True  True]
# [12 96] [12 96] [ True  True]
# [61 76] [61 76] [ True  True]
# [5 3] [5 3] [ True  True]
# [68 63] [68 63] [ True  True]
# [ 3 98] [3 3] [ True False]
# [89 64] [89 64] [ True  True]
# [49 71] [49 71] [ True  True]
# [27 17] [27 17] [ True  True]
# [66 70] [66 70] [ True  True]
# [90 53] [90 53] [ True  True]
# [51 11] [51 11] [ True  True]
# [60 94] [60 94] [ True  True]
# [83 58] [83 58] [ True  True]
# [20 59] [20 59] [ True  True]
# [84 79] [84 79] [ True  True]
# [83 49] [83 49] [ True  True]
# [61 79] [61 79] [ True  True]

# %% [markdown]
# ### References
# - "Understanding LSTM Networks" http://colah.github.io/posts/2015-08-Understanding-LSTMs/
# - "Recurrent neural networks and LSTM tutorial in Python and TensorFlow" http://adventuresinmachinelearning.com/recurrent-neural-networks-lstm-tutorial-tensorflow/
# - "How to use an Encoder-Decoder LSTM to Echo Sequences of Random Integers" https://machinelearningmastery.com/how-to-use-an-encoder-decoder-lstm-to-echo-sequences-of-random-integers/
